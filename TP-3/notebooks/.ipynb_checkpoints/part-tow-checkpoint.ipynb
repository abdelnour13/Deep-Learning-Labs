# %% [markdown]
# # Necessary Packages

# %%
import os
import time
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
import optuna
import shutil
from random import sample
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm

# %% [markdown]
# # Global

# %%
figures = {}
histories = {}
durations = {}
models = {}

# %% [markdown]
# # Data Loading

# %%
df = pd.read_csv("/kaggle/input/cifar10-python-in-csv/train.csv")

# %%
train_df,val_df = train_test_split(df,test_size=0.4)
val_df,test_df = train_test_split(val_df,test_size=0.5)

print(f"train_df = {len(train_df)}")
print(f"val_df = {len(val_df)}")
print(f"test_df = {len(test_df)}")
# Out:
# train_df = 30000
# val_df = 10000
# test_df = 10000

# %%
def preprocess(dfs):
    
    datasets = []
    
    for df in dfs:
        X = df.drop(columns=["label"]) / 255.0
        y = df["label"]
        
        X = tf.convert_to_tensor(X.values)
        y = tf.convert_to_tensor(y.values)
        
        datasets.append((X,y))
        
    return datasets

# %%
train_data,val_data,test_data = preprocess([
    train_df,
    val_df,
    test_df
])

# %% [markdown]
# # Architecture

# %%
def create_model(
    optimizer=None,
    drop_out_rate : float = 0.0,
    lambda_ : float = 0.0,
    batch_normalization : bool = False,
) -> tf.keras.models.Model:

  model = tf.keras.models.Sequential(layers=[
    tf.keras.layers.Dense(128, activation=tf.keras.activations.relu),
    tf.keras.layers.Dense(
        units=64,
        activation=tf.keras.activations.relu,
        kernel_regularizer=tf.keras.regularizers.L2(l2=lambda_)
    ),
  ])

  if batch_normalization:
    model.add(tf.keras.layers.BatchNormalization(synchronized=True))

  model.add(tf.keras.layers.Dropout(rate=drop_out_rate))
  model.add(tf.keras.layers.Dense(10, activation=tf.keras.activations.softmax))

  if optimizer is not None:
    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.SparseCategoricalCrossentropy(),
        metrics=[
            tf.keras.metrics.SparseCategoricalAccuracy()
        ],
    )

  return model

# %% [markdown]
# # Training

# %%
def train(
    model,
    name,
    train_data,
    val_data,
    batch_size=32,
    epochs=50,
    callbacks=None,
    verbose='auto'
):

  tic = time.time()
  history = model.fit(
    x=train_data[0],
    y=train_data[1],
    validation_data=val_data,
    epochs=epochs,
    batch_size=batch_size,
    callbacks=callbacks,
    verbose=verbose
  )
  toc = time.time()

  duration = toc - tic

  print(f'Model took {duration:.3f} seconds to train.')

  models[name] = model
  histories[name] = history
  durations[name] = duration

# %% [markdown]
# ## Mini batch SGD

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
model = create_model(optimizer=optimizer)
train(model,
    name='Mini-Batch SGD',
    train_data=train_data,
    val_data=val_data,
)
# Out:
# Epoch 1/50
#  86/938 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2651 - sparse_categorical_accuracy: 0.1482
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1710247249.231144     113 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1710247249.248575     113 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0693 - sparse_categorical_accuracy: 0.2385
# W0000 00:00:1710247252.392271     112 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 2.0691 - sparse_categorical_accuracy: 0.2385 - val_loss: 1.8466 - val_sparse_categorical_accuracy: 0.3441
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.8058 - sparse_categorical_accuracy: 0.3578 - val_loss: 1.7773 - val_sparse_categorical_accuracy: 0.3605
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.7320 - sparse_categorical_accuracy: 0.3846 - val_loss: 1.7685 - val_sparse_categorical_accuracy: 0.3635
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6754 - sparse_categorical_accuracy: 0.4059 - val_loss: 1.7018 - val_sparse_categorical_accuracy: 0.3827
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6376 - sparse_categorical_accuracy: 0.4223 - val_loss: 1.6134 - val_sparse_categorical_accuracy: 0.4357
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5895 - sparse_categorical_accuracy: 0.4389 - val_loss: 1.6387 - val_sparse_categorical_accuracy: 0.4173
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5566 - sparse_categorical_accuracy: 0.4539 - val_loss: 1.5755 - val_sparse_categorical_accuracy: 0.4435
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5364 - sparse_categorical_accuracy: 0.4549 - val_loss: 1.5609 - val_sparse_categorical_accuracy: 0.4408
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5060 - sparse_categorical_accuracy: 0.4703 - val_loss: 1.5643 - val_sparse_categorical_accuracy: 0.4425
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4928 - sparse_categorical_accuracy: 0.4731 - val_loss: 1.5597 - val_sparse_categorical_accuracy: 0.4419
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4669 - sparse_categorical_accuracy: 0.4825 - val_loss: 1.5920 - val_sparse_categorical_accuracy: 0.4212
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4518 - sparse_categorical_accuracy: 0.4826 - val_loss: 1.4942 - val_sparse_categorical_accuracy: 0.4653
# Epoch 13/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4309 - sparse_categorical_accuracy: 0.4938 - val_loss: 1.5463 - val_sparse_categorical_accuracy: 0.4552
# Epoch 14/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4102 - sparse_categorical_accuracy: 0.5034 - val_loss: 1.5004 - val_sparse_categorical_accuracy: 0.4739
# Epoch 15/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3899 - sparse_categorical_accuracy: 0.5115 - val_loss: 1.5327 - val_sparse_categorical_accuracy: 0.4539
# Epoch 16/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3778 - sparse_categorical_accuracy: 0.5119 - val_loss: 1.5459 - val_sparse_categorical_accuracy: 0.4601
# Epoch 17/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3704 - sparse_categorical_accuracy: 0.5161 - val_loss: 1.5928 - val_sparse_categorical_accuracy: 0.4387
# Epoch 18/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3418 - sparse_categorical_accuracy: 0.5204 - val_loss: 1.5007 - val_sparse_categorical_accuracy: 0.4680
# Epoch 19/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3282 - sparse_categorical_accuracy: 0.5325 - val_loss: 1.4850 - val_sparse_categorical_accuracy: 0.4783
# Epoch 20/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3182 - sparse_categorical_accuracy: 0.5354 - val_loss: 1.5668 - val_sparse_categorical_accuracy: 0.4450
# Epoch 21/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3029 - sparse_categorical_accuracy: 0.5375 - val_loss: 1.4776 - val_sparse_categorical_accuracy: 0.4829
# Epoch 22/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2922 - sparse_categorical_accuracy: 0.5423 - val_loss: 1.6140 - val_sparse_categorical_accuracy: 0.4339
# Epoch 23/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2843 - sparse_categorical_accuracy: 0.5469 - val_loss: 1.5119 - val_sparse_categorical_accuracy: 0.4689
# Epoch 24/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2725 - sparse_categorical_accuracy: 0.5494 - val_loss: 1.5387 - val_sparse_categorical_accuracy: 0.4734
# Epoch 25/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2666 - sparse_categorical_accuracy: 0.5515 - val_loss: 1.4972 - val_sparse_categorical_accuracy: 0.4752
# Epoch 26/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2606 - sparse_categorical_accuracy: 0.5569 - val_loss: 1.4766 - val_sparse_categorical_accuracy: 0.4847
# Epoch 27/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2458 - sparse_categorical_accuracy: 0.5623 - val_loss: 1.4588 - val_sparse_categorical_accuracy: 0.4885
# Epoch 28/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2207 - sparse_categorical_accuracy: 0.5705 - val_loss: 1.5440 - val_sparse_categorical_accuracy: 0.4699
# Epoch 29/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2030 - sparse_categorical_accuracy: 0.5708 - val_loss: 1.5461 - val_sparse_categorical_accuracy: 0.4698
# Epoch 30/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2213 - sparse_categorical_accuracy: 0.5676 - val_loss: 1.5684 - val_sparse_categorical_accuracy: 0.4579
# Epoch 31/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2093 - sparse_categorical_accuracy: 0.5684 - val_loss: 1.5256 - val_sparse_categorical_accuracy: 0.4790
# Epoch 32/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1926 - sparse_categorical_accuracy: 0.5799 - val_loss: 1.5535 - val_sparse_categorical_accuracy: 0.4778
# Epoch 33/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1761 - sparse_categorical_accuracy: 0.5844 - val_loss: 1.4865 - val_sparse_categorical_accuracy: 0.4904
# Epoch 34/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1706 - sparse_categorical_accuracy: 0.5882 - val_loss: 1.5009 - val_sparse_categorical_accuracy: 0.4836
# Epoch 35/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1561 - sparse_categorical_accuracy: 0.5931 - val_loss: 1.4750 - val_sparse_categorical_accuracy: 0.4890
# Epoch 36/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1568 - sparse_categorical_accuracy: 0.5943 - val_loss: 1.4712 - val_sparse_categorical_accuracy: 0.4921
# Epoch 37/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1373 - sparse_categorical_accuracy: 0.6037 - val_loss: 1.5702 - val_sparse_categorical_accuracy: 0.4728
# Epoch 38/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1407 - sparse_categorical_accuracy: 0.5969 - val_loss: 1.5530 - val_sparse_categorical_accuracy: 0.4671
# Epoch 39/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1250 - sparse_categorical_accuracy: 0.6014 - val_loss: 1.5782 - val_sparse_categorical_accuracy: 0.4711
# Epoch 40/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1065 - sparse_categorical_accuracy: 0.6131 - val_loss: 1.4958 - val_sparse_categorical_accuracy: 0.4860
# Epoch 41/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1063 - sparse_categorical_accuracy: 0.6084 - val_loss: 1.5066 - val_sparse_categorical_accuracy: 0.4878
# Epoch 42/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.0948 - sparse_categorical_accuracy: 0.6109 - val_loss: 1.6327 - val_sparse_categorical_accuracy: 0.4442
# Epoch 43/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.0843 - sparse_categorical_accuracy: 0.6154 - val_loss: 1.5911 - val_sparse_categorical_accuracy: 0.4632
# Epoch 44/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.0847 - sparse_categorical_accuracy: 0.6191 - val_loss: 1.5654 - val_sparse_categorical_accuracy: 0.4648
# Epoch 45/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.0750 - sparse_categorical_accuracy: 0.6168 - val_loss: 1.4966 - val_sparse_categorical_accuracy: 0.4864
# Epoch 46/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.0472 - sparse_categorical_accuracy: 0.6272 - val_loss: 1.5571 - val_sparse_categorical_accuracy: 0.4875
# Epoch 47/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.0467 - sparse_categorical_accuracy: 0.6326 - val_loss: 1.5376 - val_sparse_categorical_accuracy: 0.4873
# Epoch 48/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.0438 - sparse_categorical_accuracy: 0.6331 - val_loss: 1.5560 - val_sparse_categorical_accuracy: 0.4915
# Epoch 49/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.0303 - sparse_categorical_accuracy: 0.6393 - val_loss: 1.6469 - val_sparse_categorical_accuracy: 0.4557
# Epoch 50/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.0329 - sparse_categorical_accuracy: 0.6373 - val_loss: 1.6906 - val_sparse_categorical_accuracy: 0.4602
# Model took 106.242 seconds to train.

# %% [markdown]
# ## Mini Batch SGD With Early Stopping

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
model = create_model(optimizer=optimizer)
train(model,
    name='Mini-Batch SGD + Early Stopping',
    train_data=train_data,
    val_data=val_data,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            min_delta=0.001,
            patience=5,
            verbose=0
        )
    ]
)
# Out:
# Epoch 1/50
#  98/938 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2726 - sparse_categorical_accuracy: 0.1456
# W0000 00:00:1710247387.576125     111 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0711 - sparse_categorical_accuracy: 0.2375
# W0000 00:00:1710247390.013753     110 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2.0710 - sparse_categorical_accuracy: 0.2376 - val_loss: 1.9022 - val_sparse_categorical_accuracy: 0.3240
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.8115 - sparse_categorical_accuracy: 0.3532 - val_loss: 1.7562 - val_sparse_categorical_accuracy: 0.3713
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.7319 - sparse_categorical_accuracy: 0.3830 - val_loss: 1.7059 - val_sparse_categorical_accuracy: 0.3993
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6768 - sparse_categorical_accuracy: 0.4054 - val_loss: 1.6448 - val_sparse_categorical_accuracy: 0.4199
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6217 - sparse_categorical_accuracy: 0.4201 - val_loss: 1.7075 - val_sparse_categorical_accuracy: 0.3889
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5840 - sparse_categorical_accuracy: 0.4325 - val_loss: 1.5966 - val_sparse_categorical_accuracy: 0.4286
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5490 - sparse_categorical_accuracy: 0.4503 - val_loss: 1.7292 - val_sparse_categorical_accuracy: 0.3821
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5308 - sparse_categorical_accuracy: 0.4537 - val_loss: 1.5571 - val_sparse_categorical_accuracy: 0.4465
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5009 - sparse_categorical_accuracy: 0.4694 - val_loss: 1.5572 - val_sparse_categorical_accuracy: 0.4472
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4867 - sparse_categorical_accuracy: 0.4759 - val_loss: 1.6428 - val_sparse_categorical_accuracy: 0.4071
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4554 - sparse_categorical_accuracy: 0.4829 - val_loss: 1.6209 - val_sparse_categorical_accuracy: 0.4258
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4552 - sparse_categorical_accuracy: 0.4880 - val_loss: 1.5297 - val_sparse_categorical_accuracy: 0.4531
# Epoch 13/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4268 - sparse_categorical_accuracy: 0.4997 - val_loss: 1.5403 - val_sparse_categorical_accuracy: 0.4527
# Epoch 14/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4120 - sparse_categorical_accuracy: 0.4974 - val_loss: 1.4973 - val_sparse_categorical_accuracy: 0.4616
# Epoch 15/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3897 - sparse_categorical_accuracy: 0.5070 - val_loss: 1.5443 - val_sparse_categorical_accuracy: 0.4512
# Epoch 16/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3720 - sparse_categorical_accuracy: 0.5142 - val_loss: 1.5370 - val_sparse_categorical_accuracy: 0.4625
# Epoch 17/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3521 - sparse_categorical_accuracy: 0.5198 - val_loss: 1.6097 - val_sparse_categorical_accuracy: 0.4342
# Epoch 18/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3537 - sparse_categorical_accuracy: 0.5263 - val_loss: 1.4978 - val_sparse_categorical_accuracy: 0.4697
# Epoch 19/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3392 - sparse_categorical_accuracy: 0.5265 - val_loss: 1.4847 - val_sparse_categorical_accuracy: 0.4729
# Epoch 20/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3287 - sparse_categorical_accuracy: 0.5330 - val_loss: 1.4872 - val_sparse_categorical_accuracy: 0.4709
# Epoch 21/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3110 - sparse_categorical_accuracy: 0.5386 - val_loss: 1.4514 - val_sparse_categorical_accuracy: 0.4883
# Epoch 22/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2974 - sparse_categorical_accuracy: 0.5400 - val_loss: 1.4789 - val_sparse_categorical_accuracy: 0.4718
# Epoch 23/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2897 - sparse_categorical_accuracy: 0.5469 - val_loss: 1.4449 - val_sparse_categorical_accuracy: 0.4855
# Epoch 24/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2772 - sparse_categorical_accuracy: 0.5522 - val_loss: 1.4586 - val_sparse_categorical_accuracy: 0.4882
# Epoch 25/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2634 - sparse_categorical_accuracy: 0.5538 - val_loss: 1.5088 - val_sparse_categorical_accuracy: 0.4664
# Epoch 26/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2530 - sparse_categorical_accuracy: 0.5590 - val_loss: 1.5178 - val_sparse_categorical_accuracy: 0.4727
# Epoch 27/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2511 - sparse_categorical_accuracy: 0.5601 - val_loss: 1.4900 - val_sparse_categorical_accuracy: 0.4797
# Epoch 28/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2336 - sparse_categorical_accuracy: 0.5654 - val_loss: 1.7109 - val_sparse_categorical_accuracy: 0.4461
# Model took 59.468 seconds to train.

# %% [markdown]
# ## Mini batch SGD With L2 norm regularization

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
model = create_model(optimizer=optimizer,lambda_=0.05)
train(model,
    name='Mini-Batch SGD With L2 Nomralization',
    train_data=train_data,
    val_data=val_data,
)
# Out:
# Epoch 1/50
# 100/938 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.3393 - sparse_categorical_accuracy: 0.1615
# W0000 00:00:1710247474.216910     113 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9780 - sparse_categorical_accuracy: 0.2444
# W0000 00:00:1710247476.804911     113 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 4.9769 - sparse_categorical_accuracy: 0.2444 - val_loss: 2.6033 - val_sparse_categorical_accuracy: 0.3380
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.3743 - sparse_categorical_accuracy: 0.3288 - val_loss: 2.0208 - val_sparse_categorical_accuracy: 0.3245
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.9647 - sparse_categorical_accuracy: 0.3426 - val_loss: 1.8842 - val_sparse_categorical_accuracy: 0.3656
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.8639 - sparse_categorical_accuracy: 0.3613 - val_loss: 1.8589 - val_sparse_categorical_accuracy: 0.3576
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.8129 - sparse_categorical_accuracy: 0.3699 - val_loss: 1.8108 - val_sparse_categorical_accuracy: 0.3841
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.7836 - sparse_categorical_accuracy: 0.3916 - val_loss: 1.7978 - val_sparse_categorical_accuracy: 0.3878
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.7551 - sparse_categorical_accuracy: 0.3961 - val_loss: 1.7617 - val_sparse_categorical_accuracy: 0.3946
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.7506 - sparse_categorical_accuracy: 0.3983 - val_loss: 1.7311 - val_sparse_categorical_accuracy: 0.4109
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.7033 - sparse_categorical_accuracy: 0.4161 - val_loss: 1.7165 - val_sparse_categorical_accuracy: 0.4152
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6911 - sparse_categorical_accuracy: 0.4207 - val_loss: 1.7203 - val_sparse_categorical_accuracy: 0.4152
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6768 - sparse_categorical_accuracy: 0.4305 - val_loss: 1.6855 - val_sparse_categorical_accuracy: 0.4308
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6719 - sparse_categorical_accuracy: 0.4313 - val_loss: 1.6977 - val_sparse_categorical_accuracy: 0.4174
# Epoch 13/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6500 - sparse_categorical_accuracy: 0.4407 - val_loss: 1.6628 - val_sparse_categorical_accuracy: 0.4308
# Epoch 14/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6382 - sparse_categorical_accuracy: 0.4424 - val_loss: 1.7034 - val_sparse_categorical_accuracy: 0.4134
# Epoch 15/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6169 - sparse_categorical_accuracy: 0.4558 - val_loss: 1.6687 - val_sparse_categorical_accuracy: 0.4286
# Epoch 16/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6087 - sparse_categorical_accuracy: 0.4533 - val_loss: 1.6551 - val_sparse_categorical_accuracy: 0.4330
# Epoch 17/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6123 - sparse_categorical_accuracy: 0.4545 - val_loss: 1.6953 - val_sparse_categorical_accuracy: 0.4131
# Epoch 18/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5865 - sparse_categorical_accuracy: 0.4599 - val_loss: 1.6025 - val_sparse_categorical_accuracy: 0.4573
# Epoch 19/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5780 - sparse_categorical_accuracy: 0.4643 - val_loss: 1.6230 - val_sparse_categorical_accuracy: 0.4452
# Epoch 20/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5677 - sparse_categorical_accuracy: 0.4670 - val_loss: 1.5988 - val_sparse_categorical_accuracy: 0.4532
# Epoch 21/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5676 - sparse_categorical_accuracy: 0.4671 - val_loss: 1.6390 - val_sparse_categorical_accuracy: 0.4388
# Epoch 22/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5475 - sparse_categorical_accuracy: 0.4740 - val_loss: 1.6016 - val_sparse_categorical_accuracy: 0.4546
# Epoch 23/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5389 - sparse_categorical_accuracy: 0.4797 - val_loss: 1.5706 - val_sparse_categorical_accuracy: 0.4678
# Epoch 24/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5387 - sparse_categorical_accuracy: 0.4812 - val_loss: 1.5985 - val_sparse_categorical_accuracy: 0.4561
# Epoch 25/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5275 - sparse_categorical_accuracy: 0.4828 - val_loss: 1.6172 - val_sparse_categorical_accuracy: 0.4508
# Epoch 26/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5201 - sparse_categorical_accuracy: 0.4853 - val_loss: 1.5940 - val_sparse_categorical_accuracy: 0.4470
# Epoch 27/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5196 - sparse_categorical_accuracy: 0.4854 - val_loss: 1.6155 - val_sparse_categorical_accuracy: 0.4524
# Epoch 28/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5121 - sparse_categorical_accuracy: 0.4887 - val_loss: 1.5750 - val_sparse_categorical_accuracy: 0.4579
# Epoch 29/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5004 - sparse_categorical_accuracy: 0.4927 - val_loss: 1.5467 - val_sparse_categorical_accuracy: 0.4783
# Epoch 30/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4958 - sparse_categorical_accuracy: 0.4916 - val_loss: 1.5558 - val_sparse_categorical_accuracy: 0.4721
# Epoch 31/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4758 - sparse_categorical_accuracy: 0.5040 - val_loss: 1.6080 - val_sparse_categorical_accuracy: 0.4533
# Epoch 32/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4806 - sparse_categorical_accuracy: 0.4987 - val_loss: 1.5708 - val_sparse_categorical_accuracy: 0.4618
# Epoch 33/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4693 - sparse_categorical_accuracy: 0.5054 - val_loss: 1.5349 - val_sparse_categorical_accuracy: 0.4836
# Epoch 34/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4561 - sparse_categorical_accuracy: 0.5091 - val_loss: 1.5407 - val_sparse_categorical_accuracy: 0.4798
# Epoch 35/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4687 - sparse_categorical_accuracy: 0.5044 - val_loss: 1.5939 - val_sparse_categorical_accuracy: 0.4580
# Epoch 36/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4524 - sparse_categorical_accuracy: 0.5125 - val_loss: 1.5322 - val_sparse_categorical_accuracy: 0.4796
# Epoch 37/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4450 - sparse_categorical_accuracy: 0.5128 - val_loss: 1.5649 - val_sparse_categorical_accuracy: 0.4672
# Epoch 38/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4340 - sparse_categorical_accuracy: 0.5153 - val_loss: 1.5786 - val_sparse_categorical_accuracy: 0.4683
# Epoch 39/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4313 - sparse_categorical_accuracy: 0.5208 - val_loss: 1.5863 - val_sparse_categorical_accuracy: 0.4634
# Epoch 40/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4342 - sparse_categorical_accuracy: 0.5198 - val_loss: 1.5924 - val_sparse_categorical_accuracy: 0.4669
# Epoch 41/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4209 - sparse_categorical_accuracy: 0.5242 - val_loss: 1.5245 - val_sparse_categorical_accuracy: 0.4836
# Epoch 42/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4023 - sparse_categorical_accuracy: 0.5277 - val_loss: 1.5795 - val_sparse_categorical_accuracy: 0.4695
# Epoch 43/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4177 - sparse_categorical_accuracy: 0.5195 - val_loss: 1.5136 - val_sparse_categorical_accuracy: 0.4931
# Epoch 44/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4113 - sparse_categorical_accuracy: 0.5289 - val_loss: 1.6120 - val_sparse_categorical_accuracy: 0.4567
# Epoch 45/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4046 - sparse_categorical_accuracy: 0.5269 - val_loss: 1.5679 - val_sparse_categorical_accuracy: 0.4659
# Epoch 46/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4046 - sparse_categorical_accuracy: 0.5290 - val_loss: 1.4967 - val_sparse_categorical_accuracy: 0.4936
# Epoch 47/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3962 - sparse_categorical_accuracy: 0.5330 - val_loss: 1.4833 - val_sparse_categorical_accuracy: 0.4996
# Epoch 48/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3895 - sparse_categorical_accuracy: 0.5369 - val_loss: 1.5715 - val_sparse_categorical_accuracy: 0.4655
# Epoch 49/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3803 - sparse_categorical_accuracy: 0.5354 - val_loss: 1.5010 - val_sparse_categorical_accuracy: 0.4963
# Epoch 50/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3804 - sparse_categorical_accuracy: 0.5422 - val_loss: 1.7505 - val_sparse_categorical_accuracy: 0.4111
# Model took 105.534 seconds to train.

# %% [markdown]
# ## Mini Batch SGD With Dropout=0.2

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
model = create_model(optimizer=optimizer,drop_out_rate=0.2)
train(model,
    name='Mini-Batch SGD With Dropout Rate = 0.2',
    train_data=train_data,
    val_data=val_data,
)
# Out:
# Epoch 1/50
#  92/938 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2905 - sparse_categorical_accuracy: 0.1471
# W0000 00:00:1710247585.164095     110 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1116 - sparse_categorical_accuracy: 0.2260
# W0000 00:00:1710247588.933164     110 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 2.1115 - sparse_categorical_accuracy: 0.2260 - val_loss: 1.8691 - val_sparse_categorical_accuracy: 0.3356
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.8687 - sparse_categorical_accuracy: 0.3343 - val_loss: 1.7746 - val_sparse_categorical_accuracy: 0.3745
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.8015 - sparse_categorical_accuracy: 0.3568 - val_loss: 1.7263 - val_sparse_categorical_accuracy: 0.3951
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.7634 - sparse_categorical_accuracy: 0.3696 - val_loss: 1.7224 - val_sparse_categorical_accuracy: 0.3836
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.7110 - sparse_categorical_accuracy: 0.3954 - val_loss: 1.6644 - val_sparse_categorical_accuracy: 0.4198
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6841 - sparse_categorical_accuracy: 0.4048 - val_loss: 1.6310 - val_sparse_categorical_accuracy: 0.4232
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6609 - sparse_categorical_accuracy: 0.4134 - val_loss: 1.6599 - val_sparse_categorical_accuracy: 0.4041
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6341 - sparse_categorical_accuracy: 0.4184 - val_loss: 1.5926 - val_sparse_categorical_accuracy: 0.4420
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5987 - sparse_categorical_accuracy: 0.4357 - val_loss: 1.7294 - val_sparse_categorical_accuracy: 0.3861
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5937 - sparse_categorical_accuracy: 0.4369 - val_loss: 1.5948 - val_sparse_categorical_accuracy: 0.4269
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5707 - sparse_categorical_accuracy: 0.4469 - val_loss: 1.6071 - val_sparse_categorical_accuracy: 0.4214
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5502 - sparse_categorical_accuracy: 0.4507 - val_loss: 1.5443 - val_sparse_categorical_accuracy: 0.4508
# Epoch 13/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5185 - sparse_categorical_accuracy: 0.4613 - val_loss: 1.5239 - val_sparse_categorical_accuracy: 0.4593
# Epoch 14/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5132 - sparse_categorical_accuracy: 0.4655 - val_loss: 1.5654 - val_sparse_categorical_accuracy: 0.4398
# Epoch 15/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5050 - sparse_categorical_accuracy: 0.4658 - val_loss: 1.5554 - val_sparse_categorical_accuracy: 0.4471
# Epoch 16/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4861 - sparse_categorical_accuracy: 0.4706 - val_loss: 1.4831 - val_sparse_categorical_accuracy: 0.4747
# Epoch 17/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4816 - sparse_categorical_accuracy: 0.4757 - val_loss: 1.5450 - val_sparse_categorical_accuracy: 0.4495
# Epoch 18/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4675 - sparse_categorical_accuracy: 0.4799 - val_loss: 1.5595 - val_sparse_categorical_accuracy: 0.4459
# Epoch 19/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4400 - sparse_categorical_accuracy: 0.4882 - val_loss: 1.5490 - val_sparse_categorical_accuracy: 0.4569
# Epoch 20/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4438 - sparse_categorical_accuracy: 0.4833 - val_loss: 1.5090 - val_sparse_categorical_accuracy: 0.4665
# Epoch 21/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4167 - sparse_categorical_accuracy: 0.4920 - val_loss: 1.4834 - val_sparse_categorical_accuracy: 0.4652
# Epoch 22/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4106 - sparse_categorical_accuracy: 0.4994 - val_loss: 1.5826 - val_sparse_categorical_accuracy: 0.4357
# Epoch 23/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3978 - sparse_categorical_accuracy: 0.5035 - val_loss: 1.4784 - val_sparse_categorical_accuracy: 0.4793
# Epoch 24/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3857 - sparse_categorical_accuracy: 0.5069 - val_loss: 1.4536 - val_sparse_categorical_accuracy: 0.4834
# Epoch 25/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3856 - sparse_categorical_accuracy: 0.5053 - val_loss: 1.4614 - val_sparse_categorical_accuracy: 0.4791
# Epoch 26/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3779 - sparse_categorical_accuracy: 0.5116 - val_loss: 1.4757 - val_sparse_categorical_accuracy: 0.4813
# Epoch 27/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3743 - sparse_categorical_accuracy: 0.5081 - val_loss: 1.5348 - val_sparse_categorical_accuracy: 0.4581
# Epoch 28/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3617 - sparse_categorical_accuracy: 0.5134 - val_loss: 1.4541 - val_sparse_categorical_accuracy: 0.4813
# Epoch 29/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3326 - sparse_categorical_accuracy: 0.5211 - val_loss: 1.5465 - val_sparse_categorical_accuracy: 0.4595
# Epoch 30/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3335 - sparse_categorical_accuracy: 0.5254 - val_loss: 1.4498 - val_sparse_categorical_accuracy: 0.4899
# Epoch 31/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3269 - sparse_categorical_accuracy: 0.5261 - val_loss: 1.4625 - val_sparse_categorical_accuracy: 0.4838
# Epoch 32/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3138 - sparse_categorical_accuracy: 0.5314 - val_loss: 1.4634 - val_sparse_categorical_accuracy: 0.4880
# Epoch 33/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3207 - sparse_categorical_accuracy: 0.5266 - val_loss: 1.6517 - val_sparse_categorical_accuracy: 0.4443
# Epoch 34/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3036 - sparse_categorical_accuracy: 0.5304 - val_loss: 1.4524 - val_sparse_categorical_accuracy: 0.4876
# Epoch 35/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3131 - sparse_categorical_accuracy: 0.5322 - val_loss: 1.4752 - val_sparse_categorical_accuracy: 0.4743
# Epoch 36/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2900 - sparse_categorical_accuracy: 0.5358 - val_loss: 1.4713 - val_sparse_categorical_accuracy: 0.4834
# Epoch 37/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2848 - sparse_categorical_accuracy: 0.5416 - val_loss: 1.5300 - val_sparse_categorical_accuracy: 0.4626
# Epoch 38/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2660 - sparse_categorical_accuracy: 0.5478 - val_loss: 1.4366 - val_sparse_categorical_accuracy: 0.4913
# Epoch 39/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2631 - sparse_categorical_accuracy: 0.5487 - val_loss: 1.4958 - val_sparse_categorical_accuracy: 0.4773
# Epoch 40/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2560 - sparse_categorical_accuracy: 0.5464 - val_loss: 1.4594 - val_sparse_categorical_accuracy: 0.4902
# Epoch 41/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2435 - sparse_categorical_accuracy: 0.5505 - val_loss: 1.4622 - val_sparse_categorical_accuracy: 0.4855
# Epoch 42/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2512 - sparse_categorical_accuracy: 0.5502 - val_loss: 1.4700 - val_sparse_categorical_accuracy: 0.4865
# Epoch 43/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2223 - sparse_categorical_accuracy: 0.5679 - val_loss: 1.4932 - val_sparse_categorical_accuracy: 0.4772
# Epoch 44/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2346 - sparse_categorical_accuracy: 0.5543 - val_loss: 1.5332 - val_sparse_categorical_accuracy: 0.4812
# Epoch 45/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2167 - sparse_categorical_accuracy: 0.5643 - val_loss: 1.4174 - val_sparse_categorical_accuracy: 0.5026
# Epoch 46/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2177 - sparse_categorical_accuracy: 0.5618 - val_loss: 1.4179 - val_sparse_categorical_accuracy: 0.5021
# Epoch 47/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2166 - sparse_categorical_accuracy: 0.5667 - val_loss: 1.5036 - val_sparse_categorical_accuracy: 0.4735
# Epoch 48/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2020 - sparse_categorical_accuracy: 0.5689 - val_loss: 1.4491 - val_sparse_categorical_accuracy: 0.5001
# Epoch 49/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1873 - sparse_categorical_accuracy: 0.5729 - val_loss: 1.4517 - val_sparse_categorical_accuracy: 0.4961
# Epoch 50/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1845 - sparse_categorical_accuracy: 0.5772 - val_loss: 1.4802 - val_sparse_categorical_accuracy: 0.4836
# Model took 108.246 seconds to train.

# %% [markdown]
# ## Mini Batch SGD With Dropout=0.3

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
model = create_model(optimizer=optimizer,drop_out_rate=0.3)
train(model,
    name='Mini-Batch SGD With Dropout Rate = 0.3',
    train_data=train_data,
    val_data=val_data,
)
# Out:
# Epoch 1/50
#  92/938 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2844 - sparse_categorical_accuracy: 0.1544
# W0000 00:00:1710247698.513543     112 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1398 - sparse_categorical_accuracy: 0.2067
# W0000 00:00:1710247702.252256     111 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 2.1397 - sparse_categorical_accuracy: 0.2067 - val_loss: 1.8781 - val_sparse_categorical_accuracy: 0.3306
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.9107 - sparse_categorical_accuracy: 0.3028 - val_loss: 1.8947 - val_sparse_categorical_accuracy: 0.3120
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.8331 - sparse_categorical_accuracy: 0.3363 - val_loss: 1.7437 - val_sparse_categorical_accuracy: 0.3898
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.7867 - sparse_categorical_accuracy: 0.3591 - val_loss: 1.7010 - val_sparse_categorical_accuracy: 0.3982
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.7389 - sparse_categorical_accuracy: 0.3779 - val_loss: 1.6630 - val_sparse_categorical_accuracy: 0.4100
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.7106 - sparse_categorical_accuracy: 0.3896 - val_loss: 1.6572 - val_sparse_categorical_accuracy: 0.4060
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6882 - sparse_categorical_accuracy: 0.3999 - val_loss: 1.6501 - val_sparse_categorical_accuracy: 0.4118
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6673 - sparse_categorical_accuracy: 0.4062 - val_loss: 1.6350 - val_sparse_categorical_accuracy: 0.4181
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6407 - sparse_categorical_accuracy: 0.4196 - val_loss: 1.6029 - val_sparse_categorical_accuracy: 0.4357
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6228 - sparse_categorical_accuracy: 0.4263 - val_loss: 1.6490 - val_sparse_categorical_accuracy: 0.4160
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6054 - sparse_categorical_accuracy: 0.4305 - val_loss: 1.5593 - val_sparse_categorical_accuracy: 0.4493
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5937 - sparse_categorical_accuracy: 0.4347 - val_loss: 1.5342 - val_sparse_categorical_accuracy: 0.4551
# Epoch 13/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5794 - sparse_categorical_accuracy: 0.4370 - val_loss: 1.7135 - val_sparse_categorical_accuracy: 0.4109
# Epoch 14/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5551 - sparse_categorical_accuracy: 0.4446 - val_loss: 1.6448 - val_sparse_categorical_accuracy: 0.4085
# Epoch 15/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5317 - sparse_categorical_accuracy: 0.4600 - val_loss: 1.5878 - val_sparse_categorical_accuracy: 0.4292
# Epoch 16/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5272 - sparse_categorical_accuracy: 0.4508 - val_loss: 1.5520 - val_sparse_categorical_accuracy: 0.4526
# Epoch 17/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5105 - sparse_categorical_accuracy: 0.4622 - val_loss: 1.5122 - val_sparse_categorical_accuracy: 0.4604
# Epoch 18/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4887 - sparse_categorical_accuracy: 0.4688 - val_loss: 1.5231 - val_sparse_categorical_accuracy: 0.4644
# Epoch 19/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4855 - sparse_categorical_accuracy: 0.4718 - val_loss: 1.5381 - val_sparse_categorical_accuracy: 0.4533
# Epoch 20/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4766 - sparse_categorical_accuracy: 0.4741 - val_loss: 1.5315 - val_sparse_categorical_accuracy: 0.4514
# Epoch 21/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4542 - sparse_categorical_accuracy: 0.4805 - val_loss: 1.5116 - val_sparse_categorical_accuracy: 0.4617
# Epoch 22/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4497 - sparse_categorical_accuracy: 0.4817 - val_loss: 1.4965 - val_sparse_categorical_accuracy: 0.4698
# Epoch 23/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4460 - sparse_categorical_accuracy: 0.4872 - val_loss: 1.4724 - val_sparse_categorical_accuracy: 0.4812
# Epoch 24/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4318 - sparse_categorical_accuracy: 0.4911 - val_loss: 1.4702 - val_sparse_categorical_accuracy: 0.4777
# Epoch 25/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4170 - sparse_categorical_accuracy: 0.4960 - val_loss: 1.4550 - val_sparse_categorical_accuracy: 0.4816
# Epoch 26/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4224 - sparse_categorical_accuracy: 0.4961 - val_loss: 1.4815 - val_sparse_categorical_accuracy: 0.4665
# Epoch 27/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4022 - sparse_categorical_accuracy: 0.4960 - val_loss: 1.4722 - val_sparse_categorical_accuracy: 0.4801
# Epoch 28/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3891 - sparse_categorical_accuracy: 0.5085 - val_loss: 1.5161 - val_sparse_categorical_accuracy: 0.4652
# Epoch 29/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3941 - sparse_categorical_accuracy: 0.5015 - val_loss: 1.4569 - val_sparse_categorical_accuracy: 0.4820
# Epoch 30/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3639 - sparse_categorical_accuracy: 0.5124 - val_loss: 1.5272 - val_sparse_categorical_accuracy: 0.4516
# Epoch 31/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3665 - sparse_categorical_accuracy: 0.5154 - val_loss: 1.4502 - val_sparse_categorical_accuracy: 0.4876
# Epoch 32/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3663 - sparse_categorical_accuracy: 0.5158 - val_loss: 1.4412 - val_sparse_categorical_accuracy: 0.4884
# Epoch 33/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3616 - sparse_categorical_accuracy: 0.5173 - val_loss: 1.4841 - val_sparse_categorical_accuracy: 0.4723
# Epoch 34/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3404 - sparse_categorical_accuracy: 0.5218 - val_loss: 1.5039 - val_sparse_categorical_accuracy: 0.4620
# Epoch 35/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3426 - sparse_categorical_accuracy: 0.5246 - val_loss: 1.4641 - val_sparse_categorical_accuracy: 0.4840
# Epoch 36/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3324 - sparse_categorical_accuracy: 0.5232 - val_loss: 1.4584 - val_sparse_categorical_accuracy: 0.4795
# Epoch 37/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3283 - sparse_categorical_accuracy: 0.5271 - val_loss: 1.4201 - val_sparse_categorical_accuracy: 0.4959
# Epoch 38/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3037 - sparse_categorical_accuracy: 0.5345 - val_loss: 1.4329 - val_sparse_categorical_accuracy: 0.4968
# Epoch 39/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3115 - sparse_categorical_accuracy: 0.5354 - val_loss: 1.4703 - val_sparse_categorical_accuracy: 0.4812
# Epoch 40/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2975 - sparse_categorical_accuracy: 0.5395 - val_loss: 1.4403 - val_sparse_categorical_accuracy: 0.4931
# Epoch 41/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2929 - sparse_categorical_accuracy: 0.5408 - val_loss: 1.4984 - val_sparse_categorical_accuracy: 0.4703
# Epoch 42/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2859 - sparse_categorical_accuracy: 0.5440 - val_loss: 1.4608 - val_sparse_categorical_accuracy: 0.4880
# Epoch 43/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2756 - sparse_categorical_accuracy: 0.5418 - val_loss: 1.4460 - val_sparse_categorical_accuracy: 0.4906
# Epoch 44/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2600 - sparse_categorical_accuracy: 0.5475 - val_loss: 1.4365 - val_sparse_categorical_accuracy: 0.4958
# Epoch 45/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2695 - sparse_categorical_accuracy: 0.5497 - val_loss: 1.4379 - val_sparse_categorical_accuracy: 0.4897
# Epoch 46/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2499 - sparse_categorical_accuracy: 0.5533 - val_loss: 1.5365 - val_sparse_categorical_accuracy: 0.4693
# Epoch 47/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2536 - sparse_categorical_accuracy: 0.5562 - val_loss: 1.4629 - val_sparse_categorical_accuracy: 0.4936
# Epoch 48/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2370 - sparse_categorical_accuracy: 0.5577 - val_loss: 1.4515 - val_sparse_categorical_accuracy: 0.4850
# Epoch 49/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2478 - sparse_categorical_accuracy: 0.5544 - val_loss: 1.5438 - val_sparse_categorical_accuracy: 0.4619
# Epoch 50/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2414 - sparse_categorical_accuracy: 0.5529 - val_loss: 1.4199 - val_sparse_categorical_accuracy: 0.5016
# Model took 108.692 seconds to train.

# %% [markdown]
# ## Mini Batch SGD With Dropout=0.5

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
model = create_model(optimizer=optimizer,drop_out_rate=0.5)
train(model,
    name='Mini-Batch SGD With Dropout Rate = 0.5',
    train_data=train_data,
    val_data=val_data,
)
# Out:
# Epoch 1/50
#  91/938 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.3582 - sparse_categorical_accuracy: 0.1135
# W0000 00:00:1710247816.645357     112 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1890 - sparse_categorical_accuracy: 0.1809
# W0000 00:00:1710247820.450476     112 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 2.1890 - sparse_categorical_accuracy: 0.1810 - val_loss: 1.9452 - val_sparse_categorical_accuracy: 0.3046
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.9865 - sparse_categorical_accuracy: 0.2725 - val_loss: 1.8483 - val_sparse_categorical_accuracy: 0.3400
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.9003 - sparse_categorical_accuracy: 0.3086 - val_loss: 1.7871 - val_sparse_categorical_accuracy: 0.3647
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.8503 - sparse_categorical_accuracy: 0.3368 - val_loss: 1.7357 - val_sparse_categorical_accuracy: 0.3942
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.8139 - sparse_categorical_accuracy: 0.3439 - val_loss: 1.7165 - val_sparse_categorical_accuracy: 0.3983
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.7939 - sparse_categorical_accuracy: 0.3495 - val_loss: 1.7192 - val_sparse_categorical_accuracy: 0.3824
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.7811 - sparse_categorical_accuracy: 0.3664 - val_loss: 1.6680 - val_sparse_categorical_accuracy: 0.4121
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.7323 - sparse_categorical_accuracy: 0.3831 - val_loss: 1.6381 - val_sparse_categorical_accuracy: 0.4255
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.7230 - sparse_categorical_accuracy: 0.3840 - val_loss: 1.6399 - val_sparse_categorical_accuracy: 0.4129
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.7096 - sparse_categorical_accuracy: 0.3902 - val_loss: 1.6691 - val_sparse_categorical_accuracy: 0.4104
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6820 - sparse_categorical_accuracy: 0.4060 - val_loss: 1.6708 - val_sparse_categorical_accuracy: 0.3927
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6748 - sparse_categorical_accuracy: 0.4041 - val_loss: 1.5892 - val_sparse_categorical_accuracy: 0.4456
# Epoch 13/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6554 - sparse_categorical_accuracy: 0.4120 - val_loss: 1.5644 - val_sparse_categorical_accuracy: 0.4456
# Epoch 14/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6359 - sparse_categorical_accuracy: 0.4180 - val_loss: 1.6471 - val_sparse_categorical_accuracy: 0.4183
# Epoch 15/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6324 - sparse_categorical_accuracy: 0.4144 - val_loss: 1.5900 - val_sparse_categorical_accuracy: 0.4358
# Epoch 16/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6178 - sparse_categorical_accuracy: 0.4247 - val_loss: 1.5588 - val_sparse_categorical_accuracy: 0.4408
# Epoch 17/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5984 - sparse_categorical_accuracy: 0.4321 - val_loss: 1.5514 - val_sparse_categorical_accuracy: 0.4511
# Epoch 18/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5930 - sparse_categorical_accuracy: 0.4353 - val_loss: 1.5450 - val_sparse_categorical_accuracy: 0.4532
# Epoch 19/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5789 - sparse_categorical_accuracy: 0.4395 - val_loss: 1.5725 - val_sparse_categorical_accuracy: 0.4452
# Epoch 20/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5802 - sparse_categorical_accuracy: 0.4376 - val_loss: 1.5250 - val_sparse_categorical_accuracy: 0.4563
# Epoch 21/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5699 - sparse_categorical_accuracy: 0.4458 - val_loss: 1.5550 - val_sparse_categorical_accuracy: 0.4453
# Epoch 22/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5690 - sparse_categorical_accuracy: 0.4434 - val_loss: 1.5205 - val_sparse_categorical_accuracy: 0.4592
# Epoch 23/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5480 - sparse_categorical_accuracy: 0.4531 - val_loss: 1.5651 - val_sparse_categorical_accuracy: 0.4455
# Epoch 24/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5447 - sparse_categorical_accuracy: 0.4497 - val_loss: 1.5012 - val_sparse_categorical_accuracy: 0.4669
# Epoch 25/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5342 - sparse_categorical_accuracy: 0.4581 - val_loss: 1.5641 - val_sparse_categorical_accuracy: 0.4497
# Epoch 26/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5302 - sparse_categorical_accuracy: 0.4553 - val_loss: 1.4809 - val_sparse_categorical_accuracy: 0.4759
# Epoch 27/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5017 - sparse_categorical_accuracy: 0.4664 - val_loss: 1.5036 - val_sparse_categorical_accuracy: 0.4615
# Epoch 28/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4991 - sparse_categorical_accuracy: 0.4706 - val_loss: 1.4995 - val_sparse_categorical_accuracy: 0.4632
# Epoch 29/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4893 - sparse_categorical_accuracy: 0.4715 - val_loss: 1.4843 - val_sparse_categorical_accuracy: 0.4689
# Epoch 30/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4900 - sparse_categorical_accuracy: 0.4689 - val_loss: 1.5816 - val_sparse_categorical_accuracy: 0.4467
# Epoch 31/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4845 - sparse_categorical_accuracy: 0.4727 - val_loss: 1.4930 - val_sparse_categorical_accuracy: 0.4720
# Epoch 32/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4777 - sparse_categorical_accuracy: 0.4746 - val_loss: 1.5493 - val_sparse_categorical_accuracy: 0.4543
# Epoch 33/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4776 - sparse_categorical_accuracy: 0.4732 - val_loss: 1.4970 - val_sparse_categorical_accuracy: 0.4618
# Epoch 34/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4656 - sparse_categorical_accuracy: 0.4780 - val_loss: 1.4789 - val_sparse_categorical_accuracy: 0.4749
# Epoch 35/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4607 - sparse_categorical_accuracy: 0.4827 - val_loss: 1.4692 - val_sparse_categorical_accuracy: 0.4771
# Epoch 36/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4351 - sparse_categorical_accuracy: 0.4898 - val_loss: 1.4611 - val_sparse_categorical_accuracy: 0.4790
# Epoch 37/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4496 - sparse_categorical_accuracy: 0.4835 - val_loss: 1.4888 - val_sparse_categorical_accuracy: 0.4699
# Epoch 38/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4354 - sparse_categorical_accuracy: 0.4925 - val_loss: 1.4851 - val_sparse_categorical_accuracy: 0.4729
# Epoch 39/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4226 - sparse_categorical_accuracy: 0.4942 - val_loss: 1.4592 - val_sparse_categorical_accuracy: 0.4800
# Epoch 40/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4192 - sparse_categorical_accuracy: 0.4925 - val_loss: 1.5050 - val_sparse_categorical_accuracy: 0.4700
# Epoch 41/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4214 - sparse_categorical_accuracy: 0.4919 - val_loss: 1.4472 - val_sparse_categorical_accuracy: 0.4866
# Epoch 42/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4166 - sparse_categorical_accuracy: 0.4950 - val_loss: 1.7071 - val_sparse_categorical_accuracy: 0.4233
# Epoch 43/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4117 - sparse_categorical_accuracy: 0.4949 - val_loss: 1.4529 - val_sparse_categorical_accuracy: 0.4837
# Epoch 44/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4008 - sparse_categorical_accuracy: 0.4995 - val_loss: 1.4645 - val_sparse_categorical_accuracy: 0.4807
# Epoch 45/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3872 - sparse_categorical_accuracy: 0.5061 - val_loss: 1.5012 - val_sparse_categorical_accuracy: 0.4695
# Epoch 46/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3996 - sparse_categorical_accuracy: 0.5016 - val_loss: 1.4893 - val_sparse_categorical_accuracy: 0.4729
# Epoch 47/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3841 - sparse_categorical_accuracy: 0.5059 - val_loss: 1.4444 - val_sparse_categorical_accuracy: 0.4843
# Epoch 48/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3713 - sparse_categorical_accuracy: 0.5132 - val_loss: 1.4415 - val_sparse_categorical_accuracy: 0.4852
# Epoch 49/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3661 - sparse_categorical_accuracy: 0.5085 - val_loss: 1.5841 - val_sparse_categorical_accuracy: 0.4424
# Epoch 50/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3639 - sparse_categorical_accuracy: 0.5108 - val_loss: 1.4645 - val_sparse_categorical_accuracy: 0.4792
# Model took 109.682 seconds to train.

# %% [markdown]
# ## Mini Batch SGD With Batch Normalization

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
model = create_model(optimizer=optimizer,batch_normalization=True)
train(model,
    name='Mini-Batch SGD With Batch Normalization',
    train_data=train_data,
    val_data=val_data,
)
# Out:
# Epoch 1/50
#  91/938 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2809 - sparse_categorical_accuracy: 0.1914
# W0000 00:00:1710247933.742265     110 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9943 - sparse_categorical_accuracy: 0.2947
# W0000 00:00:1710247936.828462     113 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 1.9942 - sparse_categorical_accuracy: 0.2948 - val_loss: 1.8152 - val_sparse_categorical_accuracy: 0.3634
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.7565 - sparse_categorical_accuracy: 0.3796 - val_loss: 2.0661 - val_sparse_categorical_accuracy: 0.2802
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6887 - sparse_categorical_accuracy: 0.4116 - val_loss: 1.6616 - val_sparse_categorical_accuracy: 0.4191
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6230 - sparse_categorical_accuracy: 0.4332 - val_loss: 1.8953 - val_sparse_categorical_accuracy: 0.3282
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5857 - sparse_categorical_accuracy: 0.4449 - val_loss: 1.6271 - val_sparse_categorical_accuracy: 0.4261
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5361 - sparse_categorical_accuracy: 0.4592 - val_loss: 2.1839 - val_sparse_categorical_accuracy: 0.2996
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5243 - sparse_categorical_accuracy: 0.4617 - val_loss: 1.8126 - val_sparse_categorical_accuracy: 0.3742
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4882 - sparse_categorical_accuracy: 0.4726 - val_loss: 1.5840 - val_sparse_categorical_accuracy: 0.4472
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4680 - sparse_categorical_accuracy: 0.4844 - val_loss: 1.6614 - val_sparse_categorical_accuracy: 0.4224
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4639 - sparse_categorical_accuracy: 0.4864 - val_loss: 1.6513 - val_sparse_categorical_accuracy: 0.4269
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4192 - sparse_categorical_accuracy: 0.5030 - val_loss: 1.5387 - val_sparse_categorical_accuracy: 0.4595
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4207 - sparse_categorical_accuracy: 0.5009 - val_loss: 1.7568 - val_sparse_categorical_accuracy: 0.4061
# Epoch 13/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3976 - sparse_categorical_accuracy: 0.5065 - val_loss: 1.7128 - val_sparse_categorical_accuracy: 0.4111
# Epoch 14/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3850 - sparse_categorical_accuracy: 0.5108 - val_loss: 1.5492 - val_sparse_categorical_accuracy: 0.4593
# Epoch 15/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3633 - sparse_categorical_accuracy: 0.5223 - val_loss: 1.5160 - val_sparse_categorical_accuracy: 0.4729
# Epoch 16/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3399 - sparse_categorical_accuracy: 0.5299 - val_loss: 1.6862 - val_sparse_categorical_accuracy: 0.4340
# Epoch 17/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3282 - sparse_categorical_accuracy: 0.5275 - val_loss: 1.6319 - val_sparse_categorical_accuracy: 0.4471
# Epoch 18/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3373 - sparse_categorical_accuracy: 0.5318 - val_loss: 1.5689 - val_sparse_categorical_accuracy: 0.4516
# Epoch 19/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2983 - sparse_categorical_accuracy: 0.5352 - val_loss: 1.7470 - val_sparse_categorical_accuracy: 0.4022
# Epoch 20/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2917 - sparse_categorical_accuracy: 0.5456 - val_loss: 1.7781 - val_sparse_categorical_accuracy: 0.4280
# Epoch 21/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2903 - sparse_categorical_accuracy: 0.5449 - val_loss: 1.5295 - val_sparse_categorical_accuracy: 0.4790
# Epoch 22/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2848 - sparse_categorical_accuracy: 0.5438 - val_loss: 1.7251 - val_sparse_categorical_accuracy: 0.4321
# Epoch 23/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2617 - sparse_categorical_accuracy: 0.5600 - val_loss: 1.7011 - val_sparse_categorical_accuracy: 0.4202
# Epoch 24/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2524 - sparse_categorical_accuracy: 0.5589 - val_loss: 1.6150 - val_sparse_categorical_accuracy: 0.4640
# Epoch 25/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2504 - sparse_categorical_accuracy: 0.5598 - val_loss: 1.5020 - val_sparse_categorical_accuracy: 0.4804
# Epoch 26/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2339 - sparse_categorical_accuracy: 0.5695 - val_loss: 1.5305 - val_sparse_categorical_accuracy: 0.4760
# Epoch 27/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2297 - sparse_categorical_accuracy: 0.5636 - val_loss: 2.5069 - val_sparse_categorical_accuracy: 0.2901
# Epoch 28/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2018 - sparse_categorical_accuracy: 0.5776 - val_loss: 1.8022 - val_sparse_categorical_accuracy: 0.3987
# Epoch 29/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2156 - sparse_categorical_accuracy: 0.5698 - val_loss: 1.6187 - val_sparse_categorical_accuracy: 0.4525
# Epoch 30/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1850 - sparse_categorical_accuracy: 0.5785 - val_loss: 1.7934 - val_sparse_categorical_accuracy: 0.4189
# Epoch 31/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1703 - sparse_categorical_accuracy: 0.5882 - val_loss: 1.7380 - val_sparse_categorical_accuracy: 0.4442
# Epoch 32/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1686 - sparse_categorical_accuracy: 0.5904 - val_loss: 1.7181 - val_sparse_categorical_accuracy: 0.4366
# Epoch 33/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1645 - sparse_categorical_accuracy: 0.5889 - val_loss: 1.5363 - val_sparse_categorical_accuracy: 0.4735
# Epoch 34/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1616 - sparse_categorical_accuracy: 0.5888 - val_loss: 1.5531 - val_sparse_categorical_accuracy: 0.4719
# Epoch 35/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1315 - sparse_categorical_accuracy: 0.6019 - val_loss: 1.5140 - val_sparse_categorical_accuracy: 0.4921
# Epoch 36/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1306 - sparse_categorical_accuracy: 0.6006 - val_loss: 1.7842 - val_sparse_categorical_accuracy: 0.4248
# Epoch 37/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1263 - sparse_categorical_accuracy: 0.6017 - val_loss: 1.5784 - val_sparse_categorical_accuracy: 0.4810
# Epoch 38/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1177 - sparse_categorical_accuracy: 0.6040 - val_loss: 1.8885 - val_sparse_categorical_accuracy: 0.4140
# Epoch 39/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1130 - sparse_categorical_accuracy: 0.6064 - val_loss: 1.6581 - val_sparse_categorical_accuracy: 0.4581
# Epoch 40/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.0955 - sparse_categorical_accuracy: 0.6120 - val_loss: 1.6621 - val_sparse_categorical_accuracy: 0.4574
# Epoch 41/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.0977 - sparse_categorical_accuracy: 0.6135 - val_loss: 1.7143 - val_sparse_categorical_accuracy: 0.4503
# Epoch 42/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.0829 - sparse_categorical_accuracy: 0.6180 - val_loss: 1.5448 - val_sparse_categorical_accuracy: 0.4815
# Epoch 43/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.0887 - sparse_categorical_accuracy: 0.6157 - val_loss: 1.8493 - val_sparse_categorical_accuracy: 0.4264
# Epoch 44/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.0722 - sparse_categorical_accuracy: 0.6235 - val_loss: 1.8455 - val_sparse_categorical_accuracy: 0.4411
# Epoch 45/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.0792 - sparse_categorical_accuracy: 0.6184 - val_loss: 1.7034 - val_sparse_categorical_accuracy: 0.4469
# Epoch 46/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.0676 - sparse_categorical_accuracy: 0.6227 - val_loss: 1.7148 - val_sparse_categorical_accuracy: 0.4426
# Epoch 47/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.0464 - sparse_categorical_accuracy: 0.6290 - val_loss: 1.7161 - val_sparse_categorical_accuracy: 0.4672
# Epoch 48/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.0433 - sparse_categorical_accuracy: 0.6307 - val_loss: 1.7409 - val_sparse_categorical_accuracy: 0.4467
# Epoch 49/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.0467 - sparse_categorical_accuracy: 0.6312 - val_loss: 1.8271 - val_sparse_categorical_accuracy: 0.4205
# Epoch 50/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.0301 - sparse_categorical_accuracy: 0.6319 - val_loss: 1.8256 - val_sparse_categorical_accuracy: 0.4390
# Model took 109.906 seconds to train.

# %% [markdown]
# ## Random Search

# %%
def objective(trial : optuna.trial.Trial):

  lr = trial.suggest_float("lr", low=0.001,high=0.1,log=True)
  dropout_rate = trial.suggest_float("dropout_rate", low=0.2,high=0.6,log=True)
  batch_size = trial.suggest_categorical("batch_size", choices=[16,32,64,128])

  optimizer = tf.keras.optimizers.SGD(learning_rate=lr)
  model = create_model(
      optimizer=optimizer,
      drop_out_rate=dropout_rate,
  )

  print(f"lr = {lr},dropout_rate = {dropout_rate},batch_size = {batch_size}")

  train(model,
      name='Random Search',
      train_data=train_data,
      val_data=val_data,
      verbose=0,
      batch_size=batch_size
  )

  loss, accuracy = model.evaluate(val_data[0],val_data[1])

  return accuracy

# %%
study = optuna.create_study(direction="maximize")
# Out:
# [I 2024-03-12 12:54:38,120] A new study created in memory with name: no-name-829ecba5-da57-494e-b36b-41d67809e24b

# %%
study.optimize(func=objective,n_trials=20)
# Out:
# lr = 0.0010598109552334455,dropout_rate = 0.513020784636275,batch_size = 128
# Model took 40.321 seconds to train.
# 101/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8425 - sparse_categorical_accuracy: 0.3780
# W0000 00:00:1710248133.779945     110 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.8317 - sparse_categorical_accuracy: 0.3804
# [I 2024-03-12 12:55:34,274] Trial 0 finished with value: 0.38269999623298645 and parameters: {'lr': 0.0010598109552334455, 'dropout_rate': 0.513020784636275, 'batch_size': 128}. Best is trial 0 with value: 0.38269999623298645.
# lr = 0.02298857335504371,dropout_rate = 0.37785569706274347,batch_size = 32
# W0000 00:00:1710248137.431215     111 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1710248141.033857     110 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Model took 103.855 seconds to train.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.5781 - sparse_categorical_accuracy: 0.4593
# [I 2024-03-12 12:57:19,039] Trial 1 finished with value: 0.46700000762939453 and parameters: {'lr': 0.02298857335504371, 'dropout_rate': 0.37785569706274347, 'batch_size': 32}. Best is trial 1 with value: 0.46700000762939453.
# lr = 0.06622406747315636,dropout_rate = 0.3175610926113661,batch_size = 16
# Model took 189.027 seconds to train.
#  97/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5951 - sparse_categorical_accuracy: 0.4339
# W0000 00:00:1710248428.778784     111 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.5903 - sparse_categorical_accuracy: 0.4344
# [I 2024-03-12 13:00:29,509] Trial 2 finished with value: 0.4357999861240387 and parameters: {'lr': 0.06622406747315636, 'dropout_rate': 0.3175610926113661, 'batch_size': 16}. Best is trial 1 with value: 0.46700000762939453.
# lr = 0.038619105665842327,dropout_rate = 0.5212309567983231,batch_size = 16
# Model took 188.788 seconds to train.
#  99/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6230 - sparse_categorical_accuracy: 0.4229
# W0000 00:00:1710248619.014230     113 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.6064 - sparse_categorical_accuracy: 0.4277
# [I 2024-03-12 13:03:39,731] Trial 3 finished with value: 0.4307999908924103 and parameters: {'lr': 0.038619105665842327, 'dropout_rate': 0.5212309567983231, 'batch_size': 16}. Best is trial 1 with value: 0.46700000762939453.
# lr = 0.006205709882805522,dropout_rate = 0.46010680840654644,batch_size = 128
# Model took 40.769 seconds to train.
#  99/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5951 - sparse_categorical_accuracy: 0.4319
# W0000 00:00:1710248661.092162     112 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.5828 - sparse_categorical_accuracy: 0.4403
# [I 2024-03-12 13:04:21,589] Trial 4 finished with value: 0.44600000977516174 and parameters: {'lr': 0.006205709882805522, 'dropout_rate': 0.46010680840654644, 'batch_size': 128}. Best is trial 1 with value: 0.46700000762939453.
# lr = 0.02169993609554532,dropout_rate = 0.39351720184966493,batch_size = 32
# W0000 00:00:1710248664.820849     113 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1710248668.653510     112 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Model took 104.072 seconds to train.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4784 - sparse_categorical_accuracy: 0.4755
# [I 2024-03-12 13:06:06,545] Trial 5 finished with value: 0.4837999939918518 and parameters: {'lr': 0.02169993609554532, 'dropout_rate': 0.39351720184966493, 'batch_size': 32}. Best is trial 5 with value: 0.4837999939918518.
# lr = 0.0010383134212247436,dropout_rate = 0.4576288468895629,batch_size = 64
# Model took 62.813 seconds to train.
# 103/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7344 - sparse_categorical_accuracy: 0.3929
# W0000 00:00:1710248829.954443     113 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.7189 - sparse_categorical_accuracy: 0.4036
# [I 2024-03-12 13:07:10,447] Trial 6 finished with value: 0.41029998660087585 and parameters: {'lr': 0.0010383134212247436, 'dropout_rate': 0.4576288468895629, 'batch_size': 64}. Best is trial 5 with value: 0.4837999939918518.
# lr = 0.030260075888962824,dropout_rate = 0.3503189449956153,batch_size = 128
# Model took 40.675 seconds to train.
#  98/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6372 - sparse_categorical_accuracy: 0.4290
# W0000 00:00:1710248871.725025     113 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.6152 - sparse_categorical_accuracy: 0.4448
# [I 2024-03-12 13:07:52,237] Trial 7 finished with value: 0.4562000036239624 and parameters: {'lr': 0.030260075888962824, 'dropout_rate': 0.3503189449956153, 'batch_size': 128}. Best is trial 5 with value: 0.4837999939918518.
# lr = 0.0011565499108226363,dropout_rate = 0.5905395406580645,batch_size = 64
# Model took 62.326 seconds to train.
# 100/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7644 - sparse_categorical_accuracy: 0.3795
# W0000 00:00:1710248935.156587     113 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.7514 - sparse_categorical_accuracy: 0.3915
# [I 2024-03-12 13:08:55,654] Trial 8 finished with value: 0.40369999408721924 and parameters: {'lr': 0.0011565499108226363, 'dropout_rate': 0.5905395406580645, 'batch_size': 64}. Best is trial 5 with value: 0.4837999939918518.
# lr = 0.003348221609044786,dropout_rate = 0.5734818594933846,batch_size = 64
# Model took 62.643 seconds to train.
# 105/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6031 - sparse_categorical_accuracy: 0.4318
# W0000 00:00:1710248998.908156     113 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.5867 - sparse_categorical_accuracy: 0.4439
# [I 2024-03-12 13:09:59,391] Trial 9 finished with value: 0.4544000029563904 and parameters: {'lr': 0.003348221609044786, 'dropout_rate': 0.5734818594933846, 'batch_size': 64}. Best is trial 5 with value: 0.4837999939918518.
# lr = 0.010895275208021209,dropout_rate = 0.23081210137399555,batch_size = 32
# W0000 00:00:1710249002.660910     113 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1710249006.404819     111 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Model took 105.466 seconds to train.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.4723 - sparse_categorical_accuracy: 0.4873
# [I 2024-03-12 13:11:45,772] Trial 10 finished with value: 0.48919999599456787 and parameters: {'lr': 0.010895275208021209, 'dropout_rate': 0.23081210137399555, 'batch_size': 32}. Best is trial 10 with value: 0.48919999599456787.
# lr = 0.012075924533741539,dropout_rate = 0.2124384482339993,batch_size = 32
# W0000 00:00:1710249109.080334     111 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1710249112.971821     112 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Model took 104.840 seconds to train.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4588 - sparse_categorical_accuracy: 0.4937
# [I 2024-03-12 13:13:31,523] Trial 11 finished with value: 0.5012000203132629 and parameters: {'lr': 0.012075924533741539, 'dropout_rate': 0.2124384482339993, 'batch_size': 32}. Best is trial 11 with value: 0.5012000203132629.
# lr = 0.00974538385136771,dropout_rate = 0.20488633921643756,batch_size = 32
# W0000 00:00:1710249214.934719     110 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1710249218.702310     110 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Model took 104.393 seconds to train.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.4368 - sparse_categorical_accuracy: 0.4951
# [I 2024-03-12 13:15:16,838] Trial 12 finished with value: 0.5008999705314636 and parameters: {'lr': 0.00974538385136771, 'dropout_rate': 0.20488633921643756, 'batch_size': 32}. Best is trial 11 with value: 0.5012000203132629.
# lr = 0.00941357843360116,dropout_rate = 0.2154304629060557,batch_size = 32
# W0000 00:00:1710249320.161767     110 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1710249323.884245     112 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Model took 105.649 seconds to train.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.4807 - sparse_categorical_accuracy: 0.4854
# [I 2024-03-12 13:17:03,454] Trial 13 finished with value: 0.49320000410079956 and parameters: {'lr': 0.00941357843360116, 'dropout_rate': 0.2154304629060557, 'batch_size': 32}. Best is trial 11 with value: 0.5012000203132629.
# lr = 0.004722354572302036,dropout_rate = 0.261107804225357,batch_size = 32
# W0000 00:00:1710249426.846219     111 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1710249430.796216     110 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Model took 104.398 seconds to train.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.4847 - sparse_categorical_accuracy: 0.4777
# [I 2024-03-12 13:18:48,773] Trial 14 finished with value: 0.48019999265670776 and parameters: {'lr': 0.004722354572302036, 'dropout_rate': 0.261107804225357, 'batch_size': 32}. Best is trial 11 with value: 0.5012000203132629.
# lr = 0.010464668408139588,dropout_rate = 0.277073260006072,batch_size = 32
# W0000 00:00:1710249532.048180     112 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1710249535.786476     111 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Model took 104.181 seconds to train.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.4658 - sparse_categorical_accuracy: 0.4922
# [I 2024-03-12 13:20:33,915] Trial 15 finished with value: 0.4959999918937683 and parameters: {'lr': 0.010464668408139588, 'dropout_rate': 0.277073260006072, 'batch_size': 32}. Best is trial 11 with value: 0.5012000203132629.
# lr = 0.0020560150477138806,dropout_rate = 0.20443791646105774,batch_size = 32
# W0000 00:00:1710249637.322650     111 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1710249641.175805     113 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Model took 105.645 seconds to train.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.5171 - sparse_categorical_accuracy: 0.4511
# [I 2024-03-12 13:22:20,495] Trial 16 finished with value: 0.46480000019073486 and parameters: {'lr': 0.0020560150477138806, 'dropout_rate': 0.20443791646105774, 'batch_size': 32}. Best is trial 11 with value: 0.5012000203132629.
# lr = 0.013028983672882901,dropout_rate = 0.2475435055276544,batch_size = 32
# W0000 00:00:1710249743.924153     111 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1710249747.690728     111 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Model took 104.442 seconds to train.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5662 - sparse_categorical_accuracy: 0.4663
# [I 2024-03-12 13:24:05,848] Trial 17 finished with value: 0.4758000075817108 and parameters: {'lr': 0.013028983672882901, 'dropout_rate': 0.2475435055276544, 'batch_size': 32}. Best is trial 11 with value: 0.5012000203132629.
# lr = 0.09839171615280543,dropout_rate = 0.2885165956330117,batch_size = 16
# Model took 191.491 seconds to train.
#  99/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7188 - sparse_categorical_accuracy: 0.3848
# W0000 00:00:1710250038.086838     111 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.7039 - sparse_categorical_accuracy: 0.4011
# [I 2024-03-12 13:27:18,795] Trial 18 finished with value: 0.40779998898506165 and parameters: {'lr': 0.09839171615280543, 'dropout_rate': 0.2885165956330117, 'batch_size': 16}. Best is trial 11 with value: 0.5012000203132629.
# lr = 0.016547047427312826,dropout_rate = 0.23278643444336333,batch_size = 32
# W0000 00:00:1710250042.152276     112 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1710250045.953483     112 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Model took 104.421 seconds to train.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4310 - sparse_categorical_accuracy: 0.5090
# [I 2024-03-12 13:29:04,124] Trial 19 finished with value: 0.5127000212669373 and parameters: {'lr': 0.016547047427312826, 'dropout_rate': 0.23278643444336333, 'batch_size': 32}. Best is trial 19 with value: 0.5127000212669373.

# %%
study.best_params
# Out:
# {'lr': 0.016547047427312826,
#  'dropout_rate': 0.23278643444336333,
#  'batch_size': 32}

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=study.best_params['lr'])
model = create_model(
    optimizer=optimizer,
    drop_out_rate=study.best_params['dropout_rate'],
)

# %%
train(model,
  name='Random Search',
  train_data=train_data,
  val_data=val_data,
  batch_size=study.best_params['batch_size']
)
# Out:
# Epoch 1/50
#  92/938 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2772 - sparse_categorical_accuracy: 0.1302
# W0000 00:00:1710250172.675940     112 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1183 - sparse_categorical_accuracy: 0.2095
# W0000 00:00:1710250176.349271     111 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 2.1182 - sparse_categorical_accuracy: 0.2096 - val_loss: 1.8584 - val_sparse_categorical_accuracy: 0.3422
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.8794 - sparse_categorical_accuracy: 0.3214 - val_loss: 1.8263 - val_sparse_categorical_accuracy: 0.3542
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.8049 - sparse_categorical_accuracy: 0.3502 - val_loss: 1.7597 - val_sparse_categorical_accuracy: 0.3751
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.7474 - sparse_categorical_accuracy: 0.3762 - val_loss: 1.6874 - val_sparse_categorical_accuracy: 0.4011
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6992 - sparse_categorical_accuracy: 0.3912 - val_loss: 1.6629 - val_sparse_categorical_accuracy: 0.4023
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6682 - sparse_categorical_accuracy: 0.4044 - val_loss: 1.6521 - val_sparse_categorical_accuracy: 0.4051
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6434 - sparse_categorical_accuracy: 0.4147 - val_loss: 1.5985 - val_sparse_categorical_accuracy: 0.4339
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6287 - sparse_categorical_accuracy: 0.4194 - val_loss: 1.5674 - val_sparse_categorical_accuracy: 0.4401
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5872 - sparse_categorical_accuracy: 0.4342 - val_loss: 1.5881 - val_sparse_categorical_accuracy: 0.4382
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5661 - sparse_categorical_accuracy: 0.4414 - val_loss: 1.6771 - val_sparse_categorical_accuracy: 0.4038
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5426 - sparse_categorical_accuracy: 0.4486 - val_loss: 1.5462 - val_sparse_categorical_accuracy: 0.4515
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5409 - sparse_categorical_accuracy: 0.4507 - val_loss: 1.5886 - val_sparse_categorical_accuracy: 0.4308
# Epoch 13/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5103 - sparse_categorical_accuracy: 0.4646 - val_loss: 1.5391 - val_sparse_categorical_accuracy: 0.4513
# Epoch 14/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5071 - sparse_categorical_accuracy: 0.4584 - val_loss: 1.5368 - val_sparse_categorical_accuracy: 0.4537
# Epoch 15/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4835 - sparse_categorical_accuracy: 0.4704 - val_loss: 1.5050 - val_sparse_categorical_accuracy: 0.4620
# Epoch 16/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4716 - sparse_categorical_accuracy: 0.4736 - val_loss: 1.5165 - val_sparse_categorical_accuracy: 0.4530
# Epoch 17/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4616 - sparse_categorical_accuracy: 0.4784 - val_loss: 1.5247 - val_sparse_categorical_accuracy: 0.4550
# Epoch 18/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4538 - sparse_categorical_accuracy: 0.4856 - val_loss: 1.5230 - val_sparse_categorical_accuracy: 0.4556
# Epoch 19/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4317 - sparse_categorical_accuracy: 0.4898 - val_loss: 1.4775 - val_sparse_categorical_accuracy: 0.4671
# Epoch 20/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4183 - sparse_categorical_accuracy: 0.4965 - val_loss: 1.4864 - val_sparse_categorical_accuracy: 0.4707
# Epoch 21/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4151 - sparse_categorical_accuracy: 0.4931 - val_loss: 1.5897 - val_sparse_categorical_accuracy: 0.4356
# Epoch 22/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4036 - sparse_categorical_accuracy: 0.4997 - val_loss: 1.5449 - val_sparse_categorical_accuracy: 0.4552
# Epoch 23/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3921 - sparse_categorical_accuracy: 0.5026 - val_loss: 1.4476 - val_sparse_categorical_accuracy: 0.4865
# Epoch 24/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3740 - sparse_categorical_accuracy: 0.5111 - val_loss: 1.4780 - val_sparse_categorical_accuracy: 0.4719
# Epoch 25/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3783 - sparse_categorical_accuracy: 0.5123 - val_loss: 1.4466 - val_sparse_categorical_accuracy: 0.4810
# Epoch 26/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3605 - sparse_categorical_accuracy: 0.5102 - val_loss: 1.4434 - val_sparse_categorical_accuracy: 0.4841
# Epoch 27/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3664 - sparse_categorical_accuracy: 0.5132 - val_loss: 1.4383 - val_sparse_categorical_accuracy: 0.4918
# Epoch 28/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3490 - sparse_categorical_accuracy: 0.5180 - val_loss: 1.4832 - val_sparse_categorical_accuracy: 0.4713
# Epoch 29/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3248 - sparse_categorical_accuracy: 0.5235 - val_loss: 1.4574 - val_sparse_categorical_accuracy: 0.4757
# Epoch 30/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3328 - sparse_categorical_accuracy: 0.5246 - val_loss: 1.4732 - val_sparse_categorical_accuracy: 0.4745
# Epoch 31/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3111 - sparse_categorical_accuracy: 0.5305 - val_loss: 1.4679 - val_sparse_categorical_accuracy: 0.4744
# Epoch 32/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3129 - sparse_categorical_accuracy: 0.5295 - val_loss: 1.5039 - val_sparse_categorical_accuracy: 0.4693
# Epoch 33/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2853 - sparse_categorical_accuracy: 0.5388 - val_loss: 1.4654 - val_sparse_categorical_accuracy: 0.4884
# Epoch 34/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2995 - sparse_categorical_accuracy: 0.5324 - val_loss: 1.4117 - val_sparse_categorical_accuracy: 0.4968
# Epoch 35/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2866 - sparse_categorical_accuracy: 0.5379 - val_loss: 1.4778 - val_sparse_categorical_accuracy: 0.4840
# Epoch 36/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2791 - sparse_categorical_accuracy: 0.5407 - val_loss: 1.4664 - val_sparse_categorical_accuracy: 0.4812
# Epoch 37/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2710 - sparse_categorical_accuracy: 0.5464 - val_loss: 1.4106 - val_sparse_categorical_accuracy: 0.5024
# Epoch 38/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2602 - sparse_categorical_accuracy: 0.5471 - val_loss: 1.4339 - val_sparse_categorical_accuracy: 0.4957
# Epoch 39/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2517 - sparse_categorical_accuracy: 0.5475 - val_loss: 1.4553 - val_sparse_categorical_accuracy: 0.4798
# Epoch 40/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2491 - sparse_categorical_accuracy: 0.5549 - val_loss: 1.4611 - val_sparse_categorical_accuracy: 0.4873
# Epoch 41/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2469 - sparse_categorical_accuracy: 0.5471 - val_loss: 1.4440 - val_sparse_categorical_accuracy: 0.4896
# Epoch 42/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2317 - sparse_categorical_accuracy: 0.5542 - val_loss: 1.4337 - val_sparse_categorical_accuracy: 0.5018
# Epoch 43/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2265 - sparse_categorical_accuracy: 0.5641 - val_loss: 1.4538 - val_sparse_categorical_accuracy: 0.4923
# Epoch 44/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2182 - sparse_categorical_accuracy: 0.5600 - val_loss: 1.4455 - val_sparse_categorical_accuracy: 0.4899
# Epoch 45/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2109 - sparse_categorical_accuracy: 0.5620 - val_loss: 1.4460 - val_sparse_categorical_accuracy: 0.4934
# Epoch 46/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2117 - sparse_categorical_accuracy: 0.5645 - val_loss: 1.4148 - val_sparse_categorical_accuracy: 0.5081
# Epoch 47/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1866 - sparse_categorical_accuracy: 0.5720 - val_loss: 1.5865 - val_sparse_categorical_accuracy: 0.4738
# Epoch 48/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1892 - sparse_categorical_accuracy: 0.5709 - val_loss: 1.4360 - val_sparse_categorical_accuracy: 0.5022
# Epoch 49/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1987 - sparse_categorical_accuracy: 0.5655 - val_loss: 1.4600 - val_sparse_categorical_accuracy: 0.4900
# Epoch 50/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1851 - sparse_categorical_accuracy: 0.5750 - val_loss: 1.4456 - val_sparse_categorical_accuracy: 0.4919
# Model took 110.400 seconds to train.

# %% [markdown]
# ## Evaluation

# %%
def evaluate(models,X_val,y_val):

  result = {
      'loss' : [],
      'accuracy' : []
  }

  index = []

  for name,model in models.items():
    loss, accuracy = model.evaluate(X_val,y_val)
    result['loss'].append(loss)
    result['accuracy'].append(accuracy)
    index.append(name)

  return pd.DataFrame(data=result,index=index)

# %%
evaluation_df = evaluate(models,val_data[0],val_data[1])
evaluation_df
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.7231 - sparse_categorical_accuracy: 0.4531
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.7349 - sparse_categorical_accuracy: 0.4363
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7644 - sparse_categorical_accuracy: 0.4065
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.4937 - sparse_categorical_accuracy: 0.4813
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4353 - sparse_categorical_accuracy: 0.4921
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4892 - sparse_categorical_accuracy: 0.4694
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.8410 - sparse_categorical_accuracy: 0.4326
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4572 - sparse_categorical_accuracy: 0.4886
#                                              loss  accuracy
# Mini-Batch SGD                           1.690596    0.4602
# Mini-Batch SGD + Early Stopping          1.710900    0.4461
# Mini-Batch SGD With L2 Nomralization     1.750531    0.4111
# Mini-Batch SGD With Dropout Rate = 0.2   1.480238    0.4836
# Mini-Batch SGD With Dropout Rate = 0.3   1.419903    0.5016
# Mini-Batch SGD With Dropout Rate = 0.5   1.464516    0.4792
# Mini-Batch SGD With Batch Normalization  1.825564    0.4390
# Random Search                            1.445588    0.4919

# %%
evaluation_df.to_csv('/kaggle/working/evaluation.csv',index=False)

# %% [markdown]
# ## Learning graphs

# %%
def plot_loss_accuracy(history):

  x = range(len(history.history['loss']))

  fig, (ax1, ax2) = plt.subplots(nrows=1,ncols=2)

  fig.set_size_inches(10, 5)

  sns.lineplot(x=x, y=history.history['loss'], ax=ax1, label='Train')
  sns.lineplot(x=x, y=history.history['val_loss'], ax=ax1, label='Validation')

  ax1.set_title('Train and validation loss vs Epoch')

  sns.lineplot(x=x, y=history.history['sparse_categorical_accuracy'], ax=ax2,label='Train')
  sns.lineplot(x=x, y=history.history['val_sparse_categorical_accuracy'], ax=ax2,label='Validation')

  ax2.set_title('Train and validation accuracy vs Epoch')

  return fig

# %%
for name,history in histories.items():
  figures[name] = plot_loss_accuracy(history)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Save the histories,durations and figures and the best model

# %%
def save_models(models):
  os.mkdir("/kaggle/working/models")
  for model_name,model in models.items():
    model.save(f'/kaggle/working/models/{model_name}.keras')

# %%
save_models(models)

# %%
def histories2df(histories):

  dfs = []

  for name,history in histories.items():
    history_df = pd.DataFrame(history.history)
    history_df['model'] = [name for _ in range(len(history_df))]
    dfs.append(history_df)

  return pd.concat(dfs)

# %%
histories_df = histories2df(histories)

# %%
histories_df.to_csv('/kaggle/working/histories_df.csv', index=False)

# %%
durations_serie = pd.Series(durations)
durations_serie
# Out:
# Mini-Batch SGD                             106.241524
# Mini-Batch SGD + Early Stopping             59.468462
# Mini-Batch SGD With L2 Nomralization       105.533829
# Mini-Batch SGD With Dropout Rate = 0.2     108.245563
# Mini-Batch SGD With Dropout Rate = 0.3     108.691776
# Mini-Batch SGD With Dropout Rate = 0.5     109.682405
# Mini-Batch SGD With Batch Normalization    109.906072
# Random Search                              110.399837
# dtype: float64

# %%
durations_serie.to_csv('/kaggle/working/durations.csv')

# %%
def save_figures(figures, path : str, create_if_not_exists : bool=True):

  if create_if_not_exists and not os.path.exists(path):
    os.mkdir(path)

  if not create_if_not_exists and not os.path.exists(path):
    raise Exception(f"{path} folder doesn't exists")

  if not os.path.isdir(path):
    raise Exception(f"{path} is not a directory")

  for name, figure in figures.items():
    name = name.replace(' ','_')+'.png'
    fig_path = os.path.join(path, name)
    figure.savefig(fig_path)

# %%
save_figures(figures, path='/kaggle/working/figures')

# %%
shutil.make_archive('/kaggle/working/cifar10-result', 'zip', '/kaggle', 'working')
# Out:
# '/kaggle/working/cifar10-result.zip'
